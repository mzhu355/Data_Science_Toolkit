# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_percentage_error
incidence_data = pd.read_csv("cleaned_incidence_data.csv")
mortality_data = pd.read_csv("cleaned_mortality_data.csv")
incidence_data.head()

print(len(incidence_data))
# Out:
# 7505

# %%
# GREY model forecasting
def grey_forecast(data, num_preds):
    data = np.array(data)
    x0 = np.cumsum(data)
    z = 0.5 * (x0[:-1] + x0[1:])
    B = np.vstack((-z, np.ones(len(z)))).T
    y = data[1:]
    [a_hat, b_hat], *_ = np.linalg.lstsq(B, y, rcond=None)
    x0_hat = np.zeros(data.shape[0] + num_preds)
    x0_hat[0] = data[0]
    for i in range(1, len(x0_hat)):
        x0_hat[i] = ((data[0] - b_hat/a_hat) * np.exp(-a_hat * (i - 1)) + b_hat/a_hat)
    x_hat = np.diff(x0_hat)

    # Plot
    # plt.figure(figsize=(12, 6))
    # plt.plot(list(range(1, len(data) + 1)), data, label='Original Data', color='blue', marker='o')
    # plt.plot(list(range(1, len(x_hat) + 1)), x_hat, label='Grey Forecast', color='red', linestyle='--', marker='o')
    # plt.xlabel('Time')
    # plt.ylabel('Value')
    # plt.title('Grey Forecasting Model')
    # plt.legend()
    # plt.show()

    return x_hat[-num_preds:]


#data = [23.3, 24, 24.1, 25.2, 24.6, 25.4, 22.2, 25.3, 23.9, 24.3, 24.9, 25.5]
data = [23.3, 47.3, 71.4, 96.6, 121.2, 146.6, 168.8, 194.1, 218.0, 242.3, 267.2, 292.7]
num_preds = 1
forecasted_values = grey_forecast(data, num_preds)
print(forecasted_values-data[-1])
# Out:
# [25.52815715]

# %%
# GREY model forecasting
def grey_forecast(data, num_preds):
    data = np.array(data)
    x0 = np.cumsum(data)
    z = 0.5 * (x0[:-1] + x0[1:])
    B = np.vstack((-z, np.ones(len(z)))).T
    y = data[1:]
    [a_hat, b_hat], *_ = np.linalg.lstsq(B, y, rcond=None)
    x0_hat = np.zeros(data.shape[0] + num_preds)
    x0_hat[0] = data[0]
    for i in range(1, len(x0_hat)):
        x0_hat[i] = ((data[0] - b_hat/a_hat) * np.exp(-a_hat * (i - 1)) + b_hat/a_hat)
    x_hat = np.diff(x0_hat)
    return x_hat[-1]


# Group
grouped_data = incidence_data.groupby(['LocationAbbr', 'TopicID', 'Question'])
new_rows = []
for name, group in grouped_data:
    last_year = group['YearEnd'].max()
    forecast_year = last_year + 1
    predicted_value = round(grey_forecast(group['DataValueAlt'].tolist(), num_preds=1),2)

    new_row = group.iloc[-1].copy()
    new_row['YearStart'] = forecast_year
    new_row['YearEnd'] = forecast_year
    new_row['DataValueAlt'] = predicted_value
    new_row['LowConfidenceLimit'] = None
    new_row['HighConfidenceLimit'] = None
    new_rows.append(new_row)

new_rows_df = pd.DataFrame(new_rows)
incidence_data = pd.concat([incidence_data, new_rows_df], ignore_index=True)

print(incidence_data)
incidence_data.to_csv('grey_predict_incidence.csv', index=False)
# Out:
#      LocationAbbr LocationDesc  LocationID  \
# 0              AK       Alaska           2
# 1              AK       Alaska           2
# 2              AK       Alaska           2
# 3              AK       Alaska           2
# 4              AK       Alaska           2
# ...           ...          ...         ...
# 8199           WY      Wyoming          56
# 8200           WY      Wyoming          56
# 8201           WY      Wyoming          56
# 8202           WY      Wyoming          56
# 8203           WY      Wyoming          56
#
#                                                 Topic TopicID  YearStart  \
# 0                                             Alcohol     ALC       2011
# 1                                             Alcohol     ALC       2012
# 2                                             Alcohol     ALC       2013
# 3                                             Alcohol     ALC       2014
# 4                                             Alcohol     ALC       2015
# ...                                               ...     ...        ...
# 8199  Nutrition, Physical Activity, and Weight Status    NPAW       2022
# 8200  Nutrition, Physical Activity, and Weight Status    NPAW       2022
# 8201                                     Older Adults     OLD       2021
# 8202                                     Older Adults     OLD       2019
# 8203                                          Tobacco     TOB       2022
#
#       YearEnd StratificationCategoryID1 StratificationID1  \
# 0        2011                   OVERALL               OVR
# 1        2012                   OVERALL               OVR
# 2        2013                   OVERALL               OVR
# 3        2014                   OVERALL               OVR
# 4        2015                   OVERALL               OVR
# ...       ...                       ...               ...
# 8199     2022                   OVERALL               OVR
# 8200     2022                   OVERALL               OVR
# 8201     2021                   OVERALL               OVR
# 8202     2019                   OVERALL               OVR
# 8203     2022                   OVERALL               OVR
#
#                                                Question QuestionID  \
# 0          heavy drinking among adults aged >= 18 years     ALC5_1
# 1          heavy drinking among adults aged >= 18 years     ALC5_1
# 2          heavy drinking among adults aged >= 18 years     ALC5_1
# 3          heavy drinking among adults aged >= 18 years     ALC5_1
# 4          heavy drinking among adults aged >= 18 years     ALC5_1
# ...                                                 ...        ...
# 8199  no leisure-time physical activity among adults...   NPAW10_0
# 8200              obesity among adults aged >= 18 years    NPAW1_1
# 8201  hospitalization for hip fracture among medicar...     OLD1_0
# 8202  prevalence of 2 or more chronic conditions amo...     OLD4_0
# 8203  current smokeless tobacco use among adults age...     TOB2_2
#
#          DataValueType DataValueTypeID DataValueUnit LowConfidenceLimit  \
# 0     Crude Prevalence         CRDPREV             %                6.2
# 1     Crude Prevalence         CRDPREV             %                5.6
# 2     Crude Prevalence         CRDPREV             %                7.1
# 3     Crude Prevalence         CRDPREV             %                7.7
# 4     Crude Prevalence         CRDPREV             %                7.0
# ...                ...             ...           ...                ...
# 8199  Crude Prevalence         CRDPREV             %               None
# 8200  Crude Prevalence         CRDPREV             %               None
# 8201            Number            NMBR           NaN               None
# 8202  Crude Prevalence         CRDPREV             %               None
# 8203  Crude Prevalence         CRDPREV             %               None
#
#      HighConfidenceLimit  DataValueAlt
# 0                    8.7          7.40
# 1                    7.8          6.60
# 2                    9.5          8.20
# 3                   10.1          8.80
# 4                   10.4          8.60
# ...                  ...           ...
# 8199                None         23.46
# 8200                None         31.36
# 8201                None        494.05
# 8202                None         51.98
# 8203                None          8.75
#
# [8204 rows x 17 columns]

# %%
# Group
grouped_data = mortality_data.groupby(['LocationAbbr', 'TopicID', 'Question'])

new_rows = []
for name, group in grouped_data:
    last_year = group['YearEnd'].max()
    forecast_year = last_year + 1
    predicted_value = round(grey_forecast(group['DataValueAlt'].tolist(), num_preds=1),2)

    new_row = group.iloc[-1].copy()
    new_row['YearStart'] = forecast_year
    new_row['YearEnd'] = forecast_year
    new_row['DataValueAlt'] = predicted_value
    new_row['LowConfidenceLimit'] = None
    new_row['HighConfidenceLimit'] = None
    new_rows.append(new_row)
new_rows_df = pd.DataFrame(new_rows)
mortality_data = pd.concat([mortality_data, new_rows_df], ignore_index=True)

print(mortality_data)
incidence_data.to_csv('grey_predict_mortality.csv', index=False)
# Out:
#      LocationAbbr LocationDesc  LocationID                   Topic TopicID  \
# 0              AK       Alaska           2                 Alcohol     ALC
# 1              AK       Alaska           2                 Alcohol     ALC
# 2              AK       Alaska           2                 Alcohol     ALC
# 3              AK       Alaska           2                 Alcohol     ALC
# 4              AK       Alaska           2                 Alcohol     ALC
# ...           ...          ...         ...                     ...     ...
# 7764           WY      Wyoming          56  Cardiovascular Disease     CVD
# 7765           WY      Wyoming          56  Cardiovascular Disease     CVD
# 7766           WY      Wyoming          56  Cardiovascular Disease     CVD
# 7767           WY      Wyoming          56                Diabetes     DIA
# 7768           WY      Wyoming          56  Overarching Conditions     OVC
#
#       YearStart  YearEnd StratificationCategoryID1 StratificationID1  \
# 0          2010     2010                   OVERALL               OVR
# 1          2011     2011                   OVERALL               OVR
# 2          2012     2012                   OVERALL               OVR
# 3          2013     2013                   OVERALL               OVR
# 4          2014     2014                   OVERALL               OVR
# ...         ...      ...                       ...               ...
# 7764       2021     2021                   OVERALL               OVR
# 7765       2021     2021                   OVERALL               OVR
# 7766       2021     2021                   OVERALL               OVR
# 7767       2021     2021                   OVERALL               OVR
# 7768       2021     2021                   OVERALL               OVR
#
#                                                Question QuestionID  \
# 0                       chronic liver disease mortality     ALC6_0
# 1                       chronic liver disease mortality     ALC6_0
# 2                       chronic liver disease mortality     ALC6_0
# 3                       chronic liver disease mortality     ALC6_0
# 4                       chronic liver disease mortality     ALC6_0
# ...                                                 ...        ...
# 7764               mortality from diseases of the heart     CVD1_2
# 7765                       mortality from heart failure     CVD1_4
# 7766       mortality from total cardiovascular diseases     CVD1_1
# 7767  mortality due to diabetes reported as any list...     DIA1_1
# 7768  premature mortality among adults aged 45-64 years     OVC5_0
#
#      DataValueType DataValueTypeID      DataValueUnit LowConfidenceLimit  \
# 0       Crude Rate         CRDRATE  cases per 100,000                7.7
# 1       Crude Rate         CRDRATE  cases per 100,000               11.1
# 2       Crude Rate         CRDRATE  cases per 100,000                9.8
# 3       Crude Rate         CRDRATE  cases per 100,000                8.9
# 4       Crude Rate         CRDRATE  cases per 100,000                9.1
# ...            ...             ...                ...                ...
# 7764    Crude Rate         CRDRATE  cases per 100,000               None
# 7765    Crude Rate         CRDRATE  cases per 100,000               None
# 7766    Crude Rate         CRDRATE  cases per 100,000               None
# 7767    Crude Rate         CRDRATE  cases per 100,000               None
# 7768    Crude Rate         CRDRATE  cases per 100,000               None
#
#      HighConfidenceLimit  DataValueAlt
# 0                   12.5          9.90
# 1                   16.7         13.70
# 2                   15.0         12.20
# 3                   13.8         11.20
# 4                   14.1         11.40
# ...                  ...           ...
# 7764                None        191.73
# 7765                None        130.26
# 7766                None        247.49
# 7767                None        111.57
# 7768                None        725.85
#
# [7769 rows x 17 columns]

# %%
# Group
grouped_data = incidence_data.groupby(['LocationAbbr', 'TopicID', 'Question'])

new_rows = []
for name, group in grouped_data:
    last_year = group['YearEnd'].max()
    forecast_year = last_year + 1
    predicted_value = round(grey_forecast(group['DataValueAlt'].tolist(), num_preds=1),2)
    new_row = group.iloc[-1].copy()
    new_row['YearStart'] = forecast_year
    new_row['YearEnd'] = forecast_year
    new_row['DataValueAlt'] = predicted_value
    new_row['LowConfidenceLimit'] = None
    new_row['HighConfidenceLimit'] = None

    new_rows.append(new_row)

new_rows_df = pd.DataFrame(new_rows)
incidence_data = pd.concat([incidence_data, new_rows_df], ignore_index=True)

print(incidence_data)
incidence_data.to_csv('grey_predict_incidence.csv', index=False)

# %%
import math
def grey_forecast(data, num_preds):
    data = np.array(data)
    x0 = np.cumsum(data)
    z = 0.5 * (x0[:-1] + x0[1:])
    B = np.vstack((-z, np.ones(len(z)))).T
    y = data[1:]
    [a_hat, b_hat], *_ = np.linalg.lstsq(B, y, rcond=None)
    x0_hat = np.zeros(data.shape[0] + num_preds)
    x0_hat[0] = data[0]
    for i in range(1, len(x0_hat)):
        x0_hat[i] = ((data[0] - b_hat/a_hat) * np.exp(-a_hat * (i - 1)) + b_hat/a_hat)
    x_hat = np.diff(x0_hat)

    return x_hat

# mortality_data
# incidence_data
grouped_data = incidence_data.groupby(['LocationAbbr', 'TopicID', 'Question'])

mse_values = []
rmse_values = []
R_squared_values = []
mape_values = []
for name, group in grouped_data:
    actual_data = list(group['DataValueAlt'][:-1])
    predict_data  = list(grey_forecast(actual_data,1)[1:])
    actual_data = actual_data[1:]
    mape_values.append(mean_absolute_percentage_error(actual_data,predict_data))
    total = 0
    for i in range(len(actual_data)):
        total += (actual_data[i] - predict_data[i]) ** 2
    MSE = (1/len(actual_data)) * total
    mse_values.append(MSE)
    RMSE=MSE**0.5
    rmse_values.append(RMSE)
    SS_res = sum((np.array(actual_data) - np.array(predict_data))**2)
    mean_actual = np.mean(actual_data)
    SS_tot = sum((np.array(actual_data) - mean_actual)**2)
    R_squared = 1 - (SS_res / SS_tot)
    R_squared_values.append(R_squared)


average_mse = np.mean(mse_values)

print('Average MSE:', average_mse)
average_rmse = np.mean(rmse_values)

print('Average RMSE:', average_rmse)
aR_squared_values = np.mean(R_squared_values)

print('Average Rsquared:', aR_squared_values)
print('MAPE:', sum(mape_values)/len(mape_values))
# Out:
# Average MSE: 77074.20889801363
# Average RMSE: 23.267068293750473
# Average Rsquared: 0.39434676888295667
